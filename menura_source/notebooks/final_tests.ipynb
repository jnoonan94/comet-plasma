# %% [markdown]
# # Final tests of 2D and 3D, medium resolution

# %% [markdown]
# |   | 2D  | 3D  |
# |---|---|---|
# | Decaying turbulence | run_004 | .  |
# | Turbulent comet | run_005  | . |
# | Laminar comet | run_006 | . |
#
# Simulations made on Jean Zay.
#
# - 2D decaying turbulence, 1024 x 512 x 2 procs, 500 ppn: 02:24:00 to 15000 iterations.
# - 2D turbulent comet, 1024 x 512 x 2 procs, 500 ppn:

# %%
from menura_utils import *
import own_tools as oT
import own_colours as oC
